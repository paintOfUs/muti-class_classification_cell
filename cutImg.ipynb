# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

url = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\test c0\\10.jpg"
img = cv.imread(url)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# Convert BGR to HSV
hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
# define range of blue color in HSV
lower_blue = np.array([40,90,90])
upper_blue = np.array([166,255,255])
# Threshold the HSV image to get only blue colors
mask = cv.inRange(hsv, lower_blue, upper_blue)
mask = cv.GaussianBlur(mask,(5,5),0)

# Create a mask for white and red colors
lower_white = np.array([0, 0, 255])
upper_white = np.array([255, 40, 255])
mask_white = cv.inRange(hsv, lower_white, upper_white)

# Combine the blue and white masks to keep both blue and white/red areas
final_mask = cv.bitwise_or(mask, mask_white)

# Bitwise-AND mask and original image
res = cv.bitwise_and(img,img, mask= final_mask)

fig,axs = plt.subplots(1, 4, figsize=(10,10))

axs[0].imshow(img)
axs[0].set(title = 'origin')

axs[1].imshow(mask,cmap='gray')
axs[1].set(title = 'mask')

axs[2].imshow(res)
axs[2].set(title = 'res')

ret,thresh = cv.threshold(final_mask,127,255,0)

contours,hierachy=cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
# Draw bounding boxes around the detected contours
# for cnt in contours:
#     x, y, w, h = cv.boundingRect(cnt)
#     img = cv.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 1)
for contour in contours:
    if cv.contourArea(contour) > 250:
        [X, Y, W, H] = cv.boundingRect(contour)
        if X > 100 and Y > 150 and H>100: 
            print(X,Y,W,H)
            box=cv.rectangle(img, (X, Y), (X + W, Y + H), (0,0,255), 2)
            roi = img[Y:Y+H, X:X+W]

plt.imshow(roi)
# Out:
# 336 178 143 161

# %% [markdown]
# # cut anh

# %%
plt.imshow(roi)

# %%
import glob
from PIL import Image

# %%
url = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\13\\"
dir = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\Test_data\\2C0"
for i, filename in enumerate(glob.glob(url+"*")):
    img = cv.imread(filename)
    print(filename)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    # Convert BGR to HSV
    hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
    # define range of blue color in HSV
    lower_blue = np.array([40,90,90])
    upper_blue = np.array([166,255,255])
    # Threshold the HSV image to get only blue colors
    mask = cv.inRange(hsv, lower_blue, upper_blue)
    mask = cv.GaussianBlur(mask,(5,5),0)

    # Create a mask for white and red colors
    lower_white = np.array([0, 0, 255])
    upper_white = np.array([255, 40, 255])
    mask_white = cv.inRange(hsv, lower_white, upper_white)

    # Combine the blue and white masks to keep both blue and white/red areas
    final_mask = cv.bitwise_or(mask, mask_white)

    # Bitwise-AND mask and original image
    res = cv.bitwise_and(img,img, mask= final_mask)
    
    ret,thresh = cv.threshold(final_mask,127,255,0)

    contours,hierachy=cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
    # Draw bounding boxes around the detected contours
    # for cnt in contours:
    #     x, y, w, h = cv.boundingRect(cnt)
    #     img = cv.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 1)
    for contour in contours:
        if cv.contourArea(contour) > 200:
            [X, Y, W, H] = cv.boundingRect(contour)
            if X > 100 and Y >130 and H > 100: 
                print(X,Y,W,H)
                box=cv.rectangle(img, (X, Y), (X + W, Y + H), (0,0,255), 2)
                roi = img[Y:Y+H, X:X+W]
    
    name = dir +"\\" + str(i) + ".jpg"
    print(name)
    cv.imwrite(name, cv.cvtColor(roi, cv.COLOR_BGR2RGB))
# Out:
# D:\important_for_study_master\DoAn\New folder\data\test\13\1.jpg
# 322 181 128 139
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\0.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\10.jpg
# 314 183 143 155
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\1.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\11.jpg
# 285 180 166 152
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\2.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\12.jpg
# 298 182 153 145
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\3.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\13.jpg
# 325 181 147 179
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\4.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\14.jpg
# 317 181 149 164
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\5.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\15.jpg
# 301 180 152 144
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\6.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\16.jpg
# 325 182 134 173
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\7.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\17.jpg
# 310 180 154 142
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\8.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\18.jpg
# 298 180 191 146
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\9.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\19.jpg
# 315 180 147 154
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\10.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\2.jpg
# 318 181 138 145
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\11.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\20.jpg
# 324 180 128 204
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\12.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\21.jpg
# 321 180 139 149
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\13.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\22.jpg
# 318 181 141 142
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\14.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\23.jpg
# 306 181 147 156
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\15.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\24.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\6.jpg
# 311 182 138 164
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\53.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\60.jpg
# 313 182 142 137
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\54.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\7.jpg
# 325 184 145 144
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\55.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\8.jpg
# 327 184 140 156
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\56.jpg
# D:\important_for_study_master\DoAn\New folder\data\test\13\9.jpg
# 303 182 164 150
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\2C0\57.jpg

# %%
url = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\0.5C\\16.jpg"
img = cv.imread(url)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# Convert BGR to HSV
hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
# define range of blue color in HSV
lower_blue = np.array([40,90,90])
upper_blue = np.array([166,255,255])
# Threshold the HSV image to get only blue colors
mask = cv.inRange(hsv, lower_blue, upper_blue)
mask = cv.GaussianBlur(mask,(5,5),0)

# Create a mask for white and red colors
lower_white = np.array([0, 0, 255])
upper_white = np.array([255, 40, 255])
mask_white = cv.inRange(hsv, lower_white, upper_white)

# Combine the blue and white masks to keep both blue and white/red areas
final_mask = cv.bitwise_or(mask, mask_white)

# Bitwise-AND mask and original image
res = cv.bitwise_and(img,img, mask= final_mask)

fig,axs = plt.subplots(1, 4, figsize=(10,10))

axs[0].imshow(img)
axs[0].set(title = 'origin')

axs[1].imshow(mask,cmap='gray')
axs[1].set(title = 'mask')

axs[2].imshow(res)
axs[2].set(title = 'res')

ret,thresh = cv.threshold(final_mask,127,255,0)

contours,hierachy=cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
# Draw bounding boxes around the detected contours
# for cnt in contours:
#     x, y, w, h = cv.boundingRect(cnt)
#     img = cv.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 1)
for contour in contours:
    if cv.contourArea(contour) > 200:
        [X, Y, W, H] = cv.boundingRect(contour)
        if X > 150 and Y > 200 and H>100: 
            print(X,Y,W,H)
            box=cv.rectangle(img, (X, Y), (X + W, Y + H), (0,0,255), 2)
            roi = img[Y:Y+H, X:X+W]

name = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\imageTesTModel\\imgaeTest.jpg"
plt.imshow(roi)
cv.imwrite(name, cv.cvtColor(roi, cv.COLOR_BGR2RGB))
# Out:
# True

# %%
url = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\0.5C\\5.jpg"
dir = "D:\\important_for_study_master\\DoAn\\New folder\\data\\test\\Test_data\\2C0"
img12 = cv.imread(url)
print(filename)
img12 = cv.cvtColor(img12, cv.COLOR_BGR2RGB)

img_cut = img12[190:355,350:530]
plt.imshow(img_cut)
# Out:
# D:\important_for_study_master\DoAn\New folder\data\test\Test_data\C0\99.jpg
